# %% [markdown]
# <a href="https://colab.research.google.com/github/trieuduongle/DVD-GAN/blob/missing-dt/Train%20KTH%20Without%20Temporal%20Discriminator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/trieuduongle/DVD-GAN.git '/content/drive/My Drive/Duong/DVD-GAN'
# Out:
# Cloning into '/content/drive/My Drive/Duong/DVD-GAN'...
# remote: Enumerating objects: 687, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 687 (delta 108), reused 102 (delta 85), pack-reused 541
# Receiving objects: 100% (687/687), 232.75 KiB | 1.30 MiB/s, done.
# Resolving deltas: 100% (426/426), done.

# %%
# %cd '/content/drive/My Drive/Duong/DVD-GAN'
# Out:
# /content/drive/My Drive/Duong/DVD-GAN

# %%
  # !git config --global user.email "duongbk1602@gmail.com"
  # !git config --global user.name "Duong Le"

# %%
# !git fetch origin && git checkout missing-dt && git pull
# Out:
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 8 (delta 4), reused 6 (delta 3), pack-reused 0
# Unpacking objects: 100% (8/8), 17.47 KiB | 10.00 KiB/s, done.
# From https://github.com/trieuduongle/DVD-GAN
#    e16752b..ed76029  missing-ds -> origin/missing-ds
#  * [new branch]      missing-dt -> origin/missing-dt
# M	scripts/data_prepare.sh
# M	scripts/download_annotations.sh
# M	scripts/download_dataset.sh
# M	scripts/train_model.sh
# M	utils/eval_hmdb51.py
# M	utils/eval_kinetics.py
# M	utils/eval_ucf101.py
# M	utils/n_frames_ucf101_hmdb51.py
# M	utils/video_jpg_ucf101_hmdb51.py
# Branch 'missing-dt' set up to track remote branch 'missing-dt' from 'origin'.
# Switched to a new branch 'missing-dt'
# Already up to date.

# %%
import torch
torch.cuda.device_count()
torch.cuda.is_available()
torch.cuda.current_device()
torch.cuda.device(0)
torch.cuda.get_device_name(0)
# Out:
# 'A100-SXM4-40GB'

# %% [markdown]
# #Trainning with KTH dataset

# %%
# !git pull
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), 380 bytes | 14.00 KiB/s, done.
# From https://github.com/trieuduongle/DVD-GAN
#    5a6b1e1..e16752b  missing-ds -> origin/missing-ds
# Updating 5a6b1e1..e16752b
# Fast-forward
#  trainer.py | 1 -
#  utils.py   | 5 +----
#  2 files changed, 1 insertion(+), 5 deletions(-)

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 KB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 KB 18.4 MB/s eta 0:00:00
# ...

# %%
# !git checkout missing-ds
# Out:
# error: pathspec 'missing-ds' did not match any file(s) known to git

# %%
# !python main.py \
  --batch_size 16 \
  --val_batch_size 8 \
  --adv_loss mse \
  --gpus 0 \
  --use_tensorboard True \
  --num_workers 8 \
  --dataname 'kth' \
  --data_root '/content/drive/My Drive/Duong/datasets/kth' \
  --total_epoch 110 \
  --sample_epoch 1 \
  --model_save_epoch 2 \
  --lr_schr onecycle \
  --g_lr 0.01 \
  --ds_lr 0.01 \
  --dt_lr 0.01 \
  --hid_S 64 \
  --hid_T 256 \
  --N_S 4 \
  --N_T 8 \
  --pre_seq_length 10 \
  --aft_seq_length 20 \
  --log_path './kth_no_dt_logs' \
  --sample_path './kth_no_dt_samples' \
  --model_save_path './kth_no_dt_models'
# Out:
# model = dvd-gan
# adv_loss = mse
# imsize = 128
# g_num = 5
# g_chn = 32
# z_dim = 120
# ds_chn = 32
# dt_chn = 32
# g_conv_dim = 64
# d_conv_dim = 64
# lambda_gp = 10
# lr_schr = onecycle
# version =
# total_epoch = 110
# d_iters = 1
# g_iters = 1
# batch_size = 16
# num_workers = 8
# g_lr = 0.01
# ds_lr = 0.01
# dt_lr = 0.01
# lr_decay = 0.9999
# beta1 = 0.0
# beta2 = 0.9
# pretrained_model = None
# train = True
# parallel = False
# gpus = ['0']
# dataset = ucf101
# use_tensorboard = True
# n_class = 101
# k_sample = 64
# n_frames = 24
# test_batch_size = 8
# image_path = ./data
# log_path = ./kth_no_dt_logs
# model_save_path = ./kth_no_dt_models
# sample_path = ./kth_no_dt_samples
# interpolate_path = ./interpolate
# log_epoch = 1
# sample_epoch = 1
# model_save_epoch = 2
# norm_value = 255
# no_mean_norm = True
# std_norm = False
# mean_dataset = activitynet
# root_path = /tmp4/potter/UCF101
# video_path = videos_jpeg
# annotation_path = annotation/ucf101_01.json
# ...
